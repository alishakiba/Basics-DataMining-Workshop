# %% [markdown]
# # Note
#
# This is to show how we are going to use libraries and an example considering inconsistencies in floating-point number calculations.
#
# These are the links I've used in the class to discuss the `matplotlib` library.
#
# * https://matplotlib.org/stable/tutorials/introductory/quick_start.html#sphx-glr-tutorials-introductory-quick-start-py
# * https://matplotlib.org/stable/plot_types/index.html
#
# We also discussed the following topics:
# * https://en.wikipedia.org/wiki/Curse_of_dimensionality
# * https://en.wikipedia.org/wiki/Dependency_hell
# * https://softwareengineering.stackexchange.com/q/332757/70157 while we discussed transactional data and log files
# * https://en.wikipedia.org/wiki/Database_model while discussing various database models
# * https://en.wikipedia.org/wiki/Kernel_regression while we discussed kernelization
# * http://scikit-learn.org/stable/modules/preprocessing.html while discussing preprocessing techniques
# * http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html while discussing data normalization
# * http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html while discussing data imputation by kNN
# * http://scikit-learn.org/stable/modules/impute.html while we just touched data imputation techniques
# * https://bootcamp.pe.gatech.edu/blog/what-is-data-mining/ and the links there in for a discussion of basic and fundamental definitions of data mining

# %%
import numpy as np

# %%
a = np.linspace(-10,10,1000)
a
# Out:
# array([-10.        ,  -9.97997998,  -9.95995996,  -9.93993994,
#         -9.91991992,  -9.8998999 ,  -9.87987988,  -9.85985986,
#         -9.83983984,  -9.81981982,  -9.7997998 ,  -9.77977978,
#         -9.75975976,  -9.73973974,  -9.71971972,  -9.6996997 ,
#         -9.67967968,  -9.65965966,  -9.63963964,  -9.61961962,
#         -9.5995996 ,  -9.57957958,  -9.55955956,  -9.53953954,
#         -9.51951952,  -9.4994995 ,  -9.47947948,  -9.45945946,
#         -9.43943944,  -9.41941942,  -9.3993994 ,  -9.37937938,
#         -9.35935936,  -9.33933934,  -9.31931932,  -9.2992993 ,
#         -9.27927928,  -9.25925926,  -9.23923924,  -9.21921922,
#         -9.1991992 ,  -9.17917918,  -9.15915916,  -9.13913914,
#         -9.11911912,  -9.0990991 ,  -9.07907908,  -9.05905906,
#         -9.03903904,  -9.01901902,  -8.998999  ,  -8.97897898,
#         -8.95895896,  -8.93893894,  -8.91891892,  -8.8988989 ,
#         -8.87887888,  -8.85885886,  -8.83883884,  -8.81881882,
# ...

# %%
import matplotlib.pyplot as plt

# %%
y = np.sin(a)
z = np.cos(a)

# %%
plt.plot(a, y)
plt.plot(a, z)
plt.title('My new diagram $\int_{0.1}^1f(x)dx$')
# Out:
# Text(0.5, 1.0, 'My new diagram $\\int_{0.1}^1f(x)dx$')

# %%
a = 2.0
b = 0.0
inc = 1e-2
for i in range(200):
    b += inc
a, b
# Out:
# (2.0, 2.0000000000000013)
